# %% [markdown]
# ### 3.8 새로운 열 만들기

# %%
import seaborn as sns

df = sns.load_dataset('mpg')

df['ratio'] = (df['mpg'] / df['weight']) * 100
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name     ratio
# 0          70    usa  chevrolet chevelle malibu  0.513699
# 1          70    usa          buick skylark 320  0.406174
# 2          70    usa         plymouth satellite  0.523865
# 3          70    usa              amc rebel sst  0.466065
# 4          70    usa                ford torino  0.492896

# %%
import numpy as np
import pandas as pd

num = pd.Series([-2, -1, 1, 2])
np.where(num >= 0)
# Out:
# (array([2, 3], dtype=int64),)

# %%
np.where(num >= 0, '양수', '음수')
# Out:
# array(['음수', '음수', '양수', '양수'], dtype='<U2')

# %%
df['horse_power_div'] = np.where(df['horsepower'] < 100, '100 미만', np.where((df['horsepower'] >= 100) & (df['horsepower'] < 200), '100 이상', np.where(df['horsepower'] >= 200, '200 이상', '기타')))
df.head(8)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
#
#    model_year origin                       name     ratio horse_power_div
# 0          70    usa  chevrolet chevelle malibu  0.513699          100 이상
# 1          70    usa          buick skylark 320  0.406174          100 이상
# 2          70    usa         plymouth satellite  0.523865          100 이상
# ...
