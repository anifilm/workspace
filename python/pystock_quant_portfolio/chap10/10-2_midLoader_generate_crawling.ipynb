# %% [markdown]
# ### 10.2 한국거래소의 업종분류 현황 및 개별지표 크롤링
#
# 10.2.1 업종분류 현환 크롤링

# %%
biz_day = '20231220'

import requests as rq
from io import BytesIO
import pandas as pd

gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'
gen_otp_stk = {
    'mktId': 'STK',
    'trdDd': biz_day,
    'money': '1',
    'csvxls_isNo': 'false',
    'name': 'fileDown',
    'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}
headers = {'Refer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader'}
otp_stk = rq.post(gen_otp_url, gen_otp_stk, headers=headers).text

print(otp_stk)
# Out:
# 9Xv3TKZCMXWL49Jv9JIYjmGB5R2A17/7jPlKK6wK6sMRtSksuLS7Bnxpl86F7dAOkunw9BBwugQaSjGAcH15eQ+BU4M2KwXZXcAScL+XhTwtBgM+EFJCxYg3zco1gIgRZqIo4cIzoURnTI8+MmkJ4m8vFLhSKmM794gFu+ThsO31lY4woqehX8j6OlXFDcfHdV4NbYo4+D2Rwcfj24VnU3Zpq3ik/Dyw3FdyOXhJkBI=

# %%
down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
down_sector_stk = rq.post(down_url, {'code': otp_stk}, headers=headers)
sector_stk = pd.read_csv(BytesIO(down_sector_stk.content), encoding='EUC-KR')

sector_stk.head()
# Out:
#      종목코드      종목명   시장구분   업종명      종가    대비   등락률           시가총액
# 0  095570   AJ네트웍스  KOSPI  서비스업    4950   -10 -0.20   224001157050
# 1  006840    AK홀딩스  KOSPI  기타금융   17080   170  1.01   226268341880
# 2  027410      BGF  KOSPI  기타금융    3980   130  3.38   380952828180
# 3  282330   BGF리테일  KOSPI   유통업  133800  1100  0.83  2312586622800
# 4  138930  BNK금융지주  KOSPI  기타금융    7180    80  1.13  2312594984840

# %%
gen_otp_ksq = {
    'mktId': 'KSQ', # 코스닥 입력
    'trdDd': biz_day,
    'money': '1',
    'csvxls_isNo': 'false',
    'name': 'fileDown',
    'url': 'dbms/MDC/STAT/standard/MDCSTAT03901'
}
otp_ksq = rq.post(gen_otp_url, gen_otp_ksq, headers=headers).text

down_sector_ksq = rq.post(down_url, {'code': otp_ksq}, headers=headers)
sector_ksq = pd.read_csv(BytesIO(down_sector_ksq.content), encoding='EUC-KR')

sector_ksq.head()
# Out:
#      종목코드         종목명    시장구분    업종명     종가   대비   등락률          시가총액
# 0  060310          3S  KOSDAQ  기계·장비   2475  -20 -0.80  120128188950
# 1  054620         APS  KOSDAQ     금융   6570  -20 -0.30  133990031970
# 2  265520       AP시스템  KOSDAQ    반도체  22950    0  0.00  350708611950
# 3  211270        AP위성  KOSDAQ   통신장비  13220  120  0.92  199388058880
# 4  126600  BGF에코머티리얼즈  KOSDAQ     화학   4515  -15 -0.33  243960236625

# %%
krx_sector = pd.concat([sector_stk, sector_ksq]).reset_index(drop=True)
krx_sector['종목명'] = krx_sector['종목명'].str.strip()
krx_sector['기준일'] = biz_day

krx_sector.head()
# Out:
#      종목코드         종목명    시장구분    업종명     종가   대비   등락률          시가총액       기준일
# 0  060310          3S  KOSDAQ  기계·장비   2475  -20 -0.80  120128188950  20231220
# 1  054620         APS  KOSDAQ     금융   6570  -20 -0.30  133990031970  20231220
# 2  265520       AP시스템  KOSDAQ    반도체  22950    0  0.00  350708611950  20231220
# 3  211270        AP위성  KOSDAQ   통신장비  13220  120  0.92  199388058880  20231220
# 4  126600  BGF에코머티리얼즈  KOSDAQ     화학   4515  -15 -0.33  243960236625  20231220

# %% [markdown]
# 10.2.2 개별종목 지표 크롤링

# %%
import requests as rq
from io import BytesIO
import pandas as pd

gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'
gen_otp_data = {
    'searchType': '1',
    'mktId': 'ALL',
    'trdDd': biz_day,
    'csvxls_isNo': 'false',
    'name': 'fileDown',
    'url': 'dbms/MDC/STAT/standard/MDCSTAT03501'
}
headers = {'Referer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader'}
otp = rq.post(gen_otp_url, gen_otp_data, headers=headers).text

down_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
krx_ind = rq.post(down_url, {'code': otp}, headers=headers)

krx_ind = pd.read_csv(BytesIO(krx_ind.content), encoding='EUC-KR')
krx_ind['종목명'] = krx_ind['종목명'].str.strip()
krx_ind['기준일'] = biz_day

krx_ind.head()
# Out:
#      종목코드     종목명     종가   대비   등락률     EPS    PER  선행 EPS  선행 PER      BPS  \
# 0  060310      3S   2475  -20 -0.80    30.0  82.50     NaN     NaN    947.0
# 1  095570  AJ네트웍스   4950  -10 -0.20   201.0  24.63   622.0    7.96   8076.0
# 2  006840   AK홀딩스  17080  170  1.01     NaN    NaN     NaN     NaN  41948.0
# 3  054620     APS   6570  -20 -0.30   505.0  13.01     NaN     NaN  10864.0
# 4  265520   AP시스템  22950    0  0.00  5463.0   4.20  5824.0    3.94  17980.0
#
#     PBR  주당배당금  배당수익률       기준일
# 0  2.61      0   0.00  20231220
# 1  0.61    270   5.45  20231220
# 2  0.41    200   1.17  20231220
# 3  0.60      0   0.00  20231220
# 4  1.28    270   1.18  20231220

# %% [markdown]
# 10.2.3 데이터 정리하기

# %%
diff = list(set(krx_sector['종목명']).symmetric_difference(set(krx_ind['종목명'])))

print(diff)
# Out:
# ['이건산업', '계룡건설', '태양금속', '한올바이오파마', '아세아시멘트', 'AJ네트웍스', '인천도시가스', '현대로템', '토니모리', '솔루스첨단소재1우', 'NPC', '교보증권', '수산인더스트리', '코스맥스비티아이', '한일철강', '세진중공업', '휴니드', '삼호개발', '롯데칠성', '롯데하이마트', '케이씨', '대한화섬', '한국주철관', '이아이디', '동양', '효성중공업', '조광페인트', '삼양패키징', '화성산업', '삼익악기', '한신기계', '무림P&P', '케이카', '팬오션', '세아제강지주', '크리스탈신소재', '코리아써우', '아이에스동서', '사조동아원', '화승엔터프라이즈', 'LS네트웍스', '한국카본', '에이블씨엔씨', '덕성', 'YG PLUS', '삼영무역', '키다리스튜디오', '세기상사', '한국종합기술', '부국철강', '덕성우', '글로벌에스엠', 'LG이노텍', '대구백화점', '진양화학', '이스타코', '대신증권2우B', '코리안리', '현대건설', '코오롱우', 'LX홀딩스', '농심', '현대백화점', '금강공업', '비상교육', '크라운해태홀딩스우', '태양금속우', '무학', 'SG글로벌', 'SK', '이구산업', '해태제과식품', '한컴라이프케어', 'KCC글라스', '한창', '동양2우B', '신풍제약', 'HDC랩스', '에이플러스에셋', 'SK디스커버리우', '삼원강재', '디아이씨', '한세예스24홀딩스', 'SK네트웍스', '우신시스템', '코오롱플라스틱', 'LS전선아시아', '아시아나IDT', '진흥기업', '동아쏘시오홀딩스', 'GRT', '한화생명', '사조씨푸드', '인팩', '한세실업', '윙입푸드', '대한제당', '모나리자', '대한해운', '삼화왕관', '시디즈', '한솔로지스틱스', 'SGC에너지', '세이브존I&C', '영흥', '포스코인터내셔널', '로스웰', '한솔홀딩스', 'HD현대인프라코어', '제일파마홀딩스', 'KSS해운', '동아타이어', '미원에스씨', '일진다이아', '코오롱글로벌', '한국제지', '영보화학', 'NPC우', '롯데손해보험', '아주스틸', '신영와코루', '일진디스플', '경동도시가스', '지누스', '예스코홀딩스', '금강공업우', 'MH에탄올', '다스코', '한국화장품제조', '금양', '광동제약', '남선알미우', '부국증권우', '롯데정밀화학', '고려산업', '삼양사', '이수스페셜티케미컬', '오리엔트바이오', 'SG세계물산', 'CJ대한통운', '두산퓨얼셀1우', '삼성화재우', '유화증권우', '가온전선', '노루페인트우', '제일기획', '오가닉티코스메틱', 'DI동일', '포스코스틸리온', '인스코비', '영풍제지', '헝셩그룹', '한국철강', '삼정펄프', '동원수산', '한화', '현대차2우B', '선진', '자이에스앤디', 'HD현대중공업', '상상인증권', '쿠쿠홀딩스', 'HLB글로벌', '퍼시스', 'KB금융', '미래에셋증권', '풀무원', '태경비케이', '크라운해태홀딩스', '화신', '한화솔루션', 'DB', '두산우', '율촌화학', '보령', '현대미포조선', '삼성화재', '삼성SDI우', 'POSCO홀딩스', '부산주공', '보해양조', '휴비스', '신세계인터내셔날', '피씨디렉트', 'LG디스플레이', '한화에어로스페이스', '한국주강', '비케이탑스', '청호ICT', '유유제약1우', '한화오션', 'KPX홀딩스', '한진칼우', '한국콜마', '영원무역', 'SK이노베이션우', '신풍', '현대지에프홀딩스', 'LX홀딩스1우', '디아이', '일동홀딩스', '덕양산업', '유안타증권', 'HD현대건설기계', '경방', '쏘카', '우진플라임', '하이트진로홀딩스우', '기신정기', '세아특수강', '이노션', '한섬', '롯데관광개발', 'LS', '에이프로젠', '국제약품', 'LG화학우', '넥스틸', '한양증권우', '넥센우', '제주은행', '비비안', '대상홀딩스', '한국금융지주', '노루페인트', '서원', '현대차', '태원물산', '하나제약', 'CJ4우(전환)', '송원산업', '고려제강', '오뚜기', '신영증권', '케이씨텍', '경인전자', '유수홀딩스', 'KG케미칼', 'HJ중공업', '한전기술', '마니커', '대림B&Co', '하이트진로2우B', '삼성에스디에스', 'GS건설', 'HL만도', '한화손해보험', 'GKL', '한국수출포장', '한미반도체', '삼성엔지니어링', '세종공업', 'OCI홀딩스', '금호건설', '롯데지주우', 'HS애드', '흥아해운', '한익스프레스', '방림', 'DRB동일', '롯데케미칼', 'LX세미콘', 'SK오션플랜트', '대한항공', '한샘', '현대오토에버', '대덕', '후성', '진흥기업우B', '소마젠', '퍼스텍', '하이트진로', '삼성전기우', 'SK케미칼우', '태림포장', '웅진', '엔씨소프트', '컬러레이', '한농화성', '진도', '에쓰씨엔지니어링', '한국화장품', '현대건설우', '한국내화', 'KC코트렐', '대성에너지', '동원F&B', '애경케미칼', '현대차우', '고스트스튜디오', '더존비즈온', '제주항공', '롯데렌탈', 'KH 필룩스', '녹십자', '동일고무벨트', '백산', '현대해상', '한일홀딩스', 'DB손해보험', '디와이파워', 'LF', 'STX중공업', '삼화전기', '한진중공업홀딩스', '세아제강', '에스엘', '하나투어', '한미글로벌', '동일제강', '한미사이언스', '한솔홈데코', '광명전기', 'SK하이닉스', '전방', 'SNT에너지', 'LG헬로비전', 'KCC', 'SNT다이내믹스', '화승인더', '녹십자홀딩스', 'KG모빌리티', '대교우B', '대양금속', '사조대림', 'AK홀딩스', '성신양회', '대창단조', '롯데에너지머티리얼즈', '두산로보틱스', '티와이홀딩스우', '성신양회우', '삼일제약', '대상홀딩스우', '한솔제지', '경보제약', '영화금속', '웅진씽크빅', '현대약품', '한일현대시멘트', '미래에셋증권우', '효성첨단소재', '이월드', '바이오노트', '대호에이엘', '코오롱모빌리티그룹우', '유유제약2우B', '미원홀딩스', '대덕1우', '동인기연', '신대양제지', 'SHD', '유니드비티플러스', '풍산홀딩스', 'BYC우', '삼진제약', '삼성카드', '팜젠사이언스', '동성제약', '대덕전자1우', '보락', '지엠비코리아', '조선선재', 'CJ CGV', 'DN오토모티브', 'NICE', '경동인베스트', '하이스틸', 'HD현대에너지솔루션', '동양피스톤', '유한양행', '티웨이항공', 'STX', '효성티앤씨', '핸즈코퍼레이션', '현대엘리베이', '윌비스', '코오롱글로벌우', 'DL우', '아시아나항공', '대한전선', '우진아이엔에스', '풍산', '조비', 'KTcs', '한전KPS', '오리온', '두올', '경농', '세원이앤씨', '신세계 I&C', '국동', '삼화페인트', '삼성물산', '한국금융지주우', '유진투자증권', '대창', '유니온', '금호건설우', '강원랜드', '까뮤이앤씨', 'LG우', 'SK증권', '영원무역홀딩스', '와이투솔루션', '미래아이앤지', '엔케이', 'TCC스틸', '이화산업', '포스코퓨처엠', '서흥', '스틱인베스트먼트', 'HSD엔진', 'HL홀딩스', '인바이오젠', 'NAVER', 'SIMPAC', 'SK이노베이션', '새론오토모티브', '한국토지신탁', '삼화콘덴서', '동국홀딩스', '동양생명', 'KT', '금호에이치티', '신성통상', '태광산업', '영풍', '효성', 'BYC', '태평양물산', '플레이그램', 'F&F홀딩스', '자화전자', 'STX엔진', '대상우', '아세아제지', 'BGF', '한솔PNS', '신풍제약우', '한화우', '대한제당우', '유니드', '카카오', '쌍방울', 'CR홀딩스', '동일산업', '현대리바트', '대한제분', '계양전기', '동양우', 'CJ씨푸드', '롯데지주', '삼일씨엔에스', '미원상사', '한성 ...

# %%
kor_ticker = pd.merge(
    krx_sector,
    krx_ind,
    on=krx_sector.columns.intersection(krx_ind.columns).tolist(),
    how='outer',
)

kor_ticker.head()
# Out:
#      종목코드         종목명    시장구분    업종명     종가   대비   등락률          시가총액  \
# 0  060310          3S  KOSDAQ  기계·장비   2475  -20 -0.80  120128188950
# 1  054620         APS  KOSDAQ     금융   6570  -20 -0.30  133990031970
# 2  265520       AP시스템  KOSDAQ    반도체  22950    0  0.00  350708611950
# 3  211270        AP위성  KOSDAQ   통신장비  13220  120  0.92  199388058880
# 4  126600  BGF에코머티리얼즈  KOSDAQ     화학   4515  -15 -0.33  243960236625
#
#         기준일     EPS    PER  선행 EPS  선행 PER      BPS   PBR  주당배당금  배당수익률
# 0  20231220    30.0  82.50     NaN     NaN    947.0  2.61    0.0   0.00
# 1  20231220   505.0  13.01     NaN     NaN  10864.0  0.60    0.0   0.00
# 2  20231220  5463.0   4.20  5824.0    3.94  17980.0  1.28  270.0   1.18
# 3  20231220   287.0  46.06   676.0   19.55   5997.0  2.20   70.0   0.53
# 4  20231220  1053.0   4.29     NaN     NaN   6585.0  0.69  100.0   2.21

# %%
print(kor_ticker[kor_ticker['종목명'].str.contains('스팩|제[0-9]+호')]['종목명'].values)
# Out:
# ['DB금융스팩10호' 'DB금융스팩11호' 'IBKS제19호스팩' 'IBKS제20호스팩' 'IBKS제21호스팩'
#  'IBKS제22호스팩' 'KB제25호스팩' 'KB제26호스팩' 'KB제27호스팩' '교보11호스팩' '교보12호스팩'
#  '교보13호스팩' '교보14호스팩' '교보15호스팩' '대신밸런스제13호스팩' '대신밸런스제14호스팩' '대신밸런스제15호스팩'
#  '대신밸런스제16호스팩' '미래에셋드림스팩1호' '미래에셋비전스팩1호' '미래에셋비전스팩2호' '미래에셋비전스팩3호'
#  '비엔케이제1호스팩' '삼성머스트스팩5호' '삼성스팩4호' '삼성스팩6호' '삼성스팩7호' '삼성스팩8호' '삼성스팩9호'
#  '상상인제3호스팩' '상상인제4호스팩' '신영스팩7호' '신영스팩8호' '신영스팩9호' '신한제10호스팩' '신한제11호스팩'
#  '신한제8호스팩' '신한제9호스팩' '에스케이증권제10호스팩' '에스케이증권제8호스팩' '에스케이증권제9호스팩'
#  '에이치엠씨제6호스팩' '엔에이치스팩20호' '엔에이치스팩23호' '엔에이치스팩24호' '엔에이치스팩25호' '엔에이치스팩26호'
#  '엔에이치스팩27호' '엔에이치스팩28호' '엔에이치스팩29호' '엔에이치스팩30호' '유안타제10호스팩' '유안타제11호스팩'
#  '유안타제12호스팩' '유안타제13호스팩' '유안타제14호스팩' '유안타제9호스팩' '유진스팩7호' '유진스팩8호' '유진스팩9호'
#  '케이비제21호스팩' '케이비제22호스팩' '키움제6호스팩' '키움제7호스팩' '키움제8호스팩' '하나26호스팩' '하나27호스팩'
#  '하나28호스팩' '하나29호스팩' '하나금융21호스팩' '하나금융22호스팩' '하나금융23호스팩' '하나금융24호스팩'
#  '하나금융25호스팩' '하나머스트7호스팩' '하이제6호스팩' '하이제7호스팩' '하이제8호스팩' '한국제11호스팩'
#  '한국제12호스팩' '한국제13호스팩' '한화플러스제2호스팩' '한화플러스제3호스팩' '한화플러스제4호스팩' '엔에이치스팩19호']

# %%
print(kor_ticker[kor_ticker['종목코드'].str[-1:] != '0']['종목명'].values)
# Out:
# ['대호특수강우' '소프트센우' '해성산업1우' 'BYC우' 'CJ4우(전환)' 'CJ씨푸드1우' 'CJ우' 'CJ제일제당 우'
#  'DL우' 'DL이앤씨2우(전환)' 'DL이앤씨우' 'GS우' 'JW중외제약2우B' 'JW중외제약우' 'LG생활건강우' 'LG우'
#  'LG전자우' 'LG화학우' 'LX하우시스우' 'LX홀딩스1우' 'NH투자증권우' 'NPC우' 'S-Oil우' 'SK디스커버리우'
#  'SK우' 'SK이노베이션우' 'SK증권우' 'SK케미칼우' '계양전기우' '금강공업우' '금호건설우' '금호석유우'
#  '깨끗한나라우' '남선알미우' '남양유업우' '넥센우' '넥센타이어1우B' '노루페인트우' '노루홀딩스우' '녹십자홀딩스2우'
#  '대교우B' '대덕1우' '대덕전자1우' '대상우' '대상홀딩스우' '대신증권2우B' '대신증권우' '대원전선우' '대한제당우'
#  '대한항공우' '덕성우' '동부건설우' '동양2우B' '동양우' '동원시스템즈우' '두산2우B' '두산우' '두산퓨얼셀1우'
#  '두산퓨얼셀2우B' '롯데지주우' '롯데칠성우' '미래에셋증권2우B' '미래에셋증권우' '부국증권우' '삼성SDI우'
#  '삼성물산우B' '삼성전기우' '삼성전자우' '삼성화재우' '삼양사우' '삼양홀딩스우' '서울식품우' '성문전자우' '성신양회우'
#  '세방우' '솔루스첨단소재1우' '솔루스첨단소재2우B' '신영증권우' '신풍제약우' '아모레G3우(전환)' '아모레G우'
#  '아모레퍼시픽우' '유안타증권우' '유유제약1우' '유유제약2우B' '유한양행우' '유화증권우' '일양약품우' '진흥기업2우B'
#  '진흥기업우B' '코리아써우' '코리아써키트2우B' '코오롱글로벌우' '코오롱모빌리티그룹우' '코오롱우' '코오롱인더우'
#  '크라운제과우' '크라운해태홀딩스우' '태양금속우' '태영건설우' '티와이홀딩스우' '하이트진로2우B' '하이트진로홀딩스우'
#  '한국금융지주우' '한양증권우' '한진칼우' '한화3우B' '한화갤러리아우' '한화솔루션우' '한화우' '한화투자증권우'
#  '현대건설우' '현대차2우B' '현대차3우B' '현대차우' '호텔신라우' '흥국화재우']

# %%
print(kor_ticker[kor_ticker['종목명'].str.endswith('리츠')]['종목명'].values)
# Out:
# []

# %%
import numpy as np

kor_ticker['종목구분'] = np.where(
    kor_ticker['종목명'].str.contains('스팩|제[0-9]+호'),
    '스팩',
    np.where(
        kor_ticker['종목코드'].str[-1:] != '0',
        '우선주',
        np.where(
            kor_ticker['종목명'].str.endswith('리츠'),
            '리츠',
            np.where(kor_ticker['종목명'].isin(diff), '기타', '보통주'),
        ),
    ),
)
kor_ticker = kor_ticker.reset_index(drop=True)
kor_ticker.columns = kor_ticker.columns.str.replace(' ', '')
kor_ticker = kor_ticker[
    ['종목코드', '종목명', '시장구분', '종가', '시가총액', '기준일', 'EPS', '선행EPS', 'BPS', '주당배당금', '종목구분']
]
kor_ticker['기준일'] = pd.to_datetime(kor_ticker['기준일'])

kor_ticker.head()
# Out:
#      종목코드         종목명    시장구분     종가          시가총액        기준일     EPS   선행EPS  \
# 0  060310          3S  KOSDAQ   2475  120128188950 2023-12-20    30.0     NaN
# 1  054620         APS  KOSDAQ   6570  133990031970 2023-12-20   505.0     NaN
# 2  265520       AP시스템  KOSDAQ  22950  350708611950 2023-12-20  5463.0  5824.0
# 3  211270        AP위성  KOSDAQ  13220  199388058880 2023-12-20   287.0   676.0
# 4  126600  BGF에코머티리얼즈  KOSDAQ   4515  243960236625 2023-12-20  1053.0     NaN
#
#        BPS  주당배당금 종목구분
# 0    947.0    0.0  보통주
# 1  10864.0    0.0  보통주
# 2  17980.0  270.0  보통주
# 3   5997.0   70.0  보통주
# 4   6585.0  100.0  보통주

# %%
# 다운로드 받은 정보 kor_ticker 테이블에 upsert 형태로 저장 (코드 작성안함)
